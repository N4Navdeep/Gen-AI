# %%
import pandas as pd

# %%
a=[32,4,36,7,43]

# %%
sr=pd.Series(a)

# %%
print(sr)
# Out:
# 0    32
# 1     4
# 2    36
# 3     7
# 4    43
# dtype: int64

# %% [markdown]
# **DataFrame**

# %%
weather={
    "temp":[32,45,30,40,31],
    "humidity":[80,60,78,21,23],
    "windspeed":[6,7,2,7,4],
    "event":["rain","sunny","snow","snow","rain"]
}

# %%
df=pd.DataFrame(weather)
df
# Out:
#    temp  humidity  windspeed  event
# 0    32        80          6   rain
# 1    45        60          7  sunny
# 2    30        78          2   snow
# 3    40        21          7   snow
# 4    31        23          4   rain

# %%
df.head(2)
# Out:
#    temp  humidity  windspeed  event
# 0    32        80          6   rain
# 1    45        60          7  sunny

# %%
df.tail(2)
# Out:
#    temp  humidity  windspeed event
# 3    40        21          7  snow
# 4    31        23          4  rain

# %%
df[["humidity","windspeed"]]
# Out:
#    humidity  windspeed
# 0        80          6
# 1        60          7
# 2        78          2
# 3        21          7
# 4        23          4

# %% [markdown]
# #loc & iloc

# %%
df.loc[0:2,["humidity","windspeed"]]
# Out:
#    humidity  windspeed
# 0        80          6
# 1        60          7
# 2        78          2

# %%
df.iloc[:4,2:]
# Out:
#    windspeed  event
# 0          6   rain
# 1          7  sunny
# 2          2   snow
# 3          7   snow

# %%
df.iloc[:,-1].unique()
# Out:
# array(['rain', 'sunny', 'snow'], dtype=object)

# %%
df[df["temp"]>30]
# Out:
#    temp  humidity  windspeed  event
# 0    32        80          6   rain
# 1    45        60          7  sunny
# 3    40        21          7   snow
# 4    31        23          4   rain

# %%
import numpy as np

weather={
    "temp":[32,45,30,40,31,90],
    "humidity":[80,60,78,21,23,np.nan],
    "windspeed":[6,7,2,7,4,np.nan],
    "event":["rain","sunny","snow","snow","rain",np.nan]
}

# %%
df1 = pd.DataFrame(weather)
print(df1)
# Out:
#    temp  humidity  windspeed  event
# 0    32      80.0        6.0   rain
# 1    45      60.0        7.0  sunny
# 2    30      78.0        2.0   snow
# 3    40      21.0        7.0   snow
# 4    31      23.0        4.0   rain
# 5    90       NaN        NaN    NaN

# %%
df1.isnull()
# Out:
#     temp  humidity  windspeed  event
# 0  False     False      False  False
# 1  False     False      False  False
# 2  False     False      False  False
# 3  False     False      False  False
# 4  False     False      False  False
# 5  False      True       True   True

# %%
df1.isnull().sum()
# Out:
# temp         0
# humidity     1
# windspeed    1
# event        1
# dtype: int64

# %% [markdown]
# * fillna(0/mean/median)
# * dropna()   {dropna(axis=0/1}
# * inplace(actual DataFrame)

# %%
df1.fillna(0)
# Out:
#    temp  humidity  windspeed  event
# 0    32      80.0        6.0   rain
# 1    45      60.0        7.0  sunny
# 2    30      78.0        2.0   snow
# 3    40      21.0        7.0   snow
# 4    31      23.0        4.0   rain
# 5    90       0.0        0.0      0

# %%
df1.dropna(axis=1)
# Out:
#    temp
# 0    32
# 1    45
# 2    30
# 3    40
# 4    31
# 5    90

# %%
df.dropna() #axis=>1
# Out:
#    temp  humidity  windspeed  event
# 0    32        80          6   rain
# 1    45        60          7  sunny
# 2    30        78          2   snow
# 3    40        21          7   snow
# 4    31        23          4   rain

# %%
df1
# Out:
#    temp  humidity  windspeed  event
# 0    32      80.0        6.0   rain
# 1    45      60.0        7.0  sunny
# 2    30      78.0        2.0   snow
# 3    40      21.0        7.0   snow
# 4    31      23.0        4.0   rain
# 5    90       NaN        NaN    NaN

# %%
df1.dropna(axis=0,inplace=True)

# %%
df1["event"]=df1["event"].map({"sunny":0, "rain":1, "snow":2})
df1
# Out:
#    temp  humidity  windspeed  event
# 0    32      80.0        6.0      1
# 1    45      60.0        7.0      0
# 2    30      78.0        2.0      2
# 3    40      21.0        7.0      2
# 4    31      23.0        4.0      1
