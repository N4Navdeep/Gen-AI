# %%
Ppl=['b','b','g','b','g']
Ppl.sort()
print(Ppl)
# Out:
# ['b', 'b', 'b', 'g', 'g']

# %%
import numpy as np
import pandas as pd

# %%
a=[10,20,30]
b= np.array(a) + 10
print(b)
print(np.sum(b))
print(np.mean(b))
print(np.min(a))
print(np.max(a))
# Out:
# [20 30 40]
# 90
# 30.0
# 10
# 30

# %%
data = {
     'Name': ['Nav','Guri','Armaan','Shurli'],
     'Marks':[69,65,72,45]
}
df = pd.DataFrame(data)
print(df)
# Out:
#      Name  Marks
# 0     Nav     69
# 1    Guri     65
# 2  Armaan     72
# 3  Shurli     45

# %%
name = ['Nav','Guri','Armaan','Shurli']
marks = [69,65,72,45]
df = pd.DataFrame({'Name': name, 'Marks': marks})
print(df)
# Out:
#      Name  Marks
# 0     Nav     69
# 1    Guri     65
# 2  Armaan     72
# 3  Shurli     45

# %%
df.head()
# Out:
#      Name  Marks
# 0     Nav     69
# 1    Guri     65
# 2  Armaan     72
# 3  Shurli     45

# %%
df.tail()
# Out:
#      Name  Marks
# 0     Nav     69
# 1    Guri     65
# 2  Armaan     72
# 3  Shurli     45

# %%
print(df['Name'])
# Out:
# 0       Nav
# 1      Guri
# 2    Armaan
# 3    Shurli
# Name: Name, dtype: object

# %%
display(df['Name'])
# Out:
# 0       Nav
# 1      Guri
# 2    Armaan
# 3    Shurli
# Name: Name, dtype: object

# %%
print(df['Marks'].mean())
print(df['Marks'].max())
print(df['Marks'].min())
# Out:
# 62.75
# 72
# 45

# %%
print(df['Marks']>70)
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# Name: Marks, dtype: bool

# %%
print(df[df['Marks']>60])
# Out:
#      Name  Marks
# 0     Nav     69
# 1    Guri     65
# 2  Armaan     72
